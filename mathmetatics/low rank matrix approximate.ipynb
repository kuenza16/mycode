# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np

# %%
a = imread('POLO.jpg')
a.shape
# Out:
# (938, 741, 3)

# %%
# code to convert single matrix
x = np.mean(a,-1)
x.shape
# Out:
# (938, 741)

# %%
img = plt.imshow(x)
img.set_cmap('gray')

# %%
U,S,VT=np.linalg.svd(x)

# %%
for term_number in range(1,50,10):
    recon =np.matrix(U[:,:term_number])*np.diag(s[:term_number])*np.matrix(VT[: term_number,:])
    plt.figure(figsize=(9,6))
    plt.imshow(recon,cmap='gray')
    plt.title('Rank'+str(term_number))
